# %%
import torch
import random
import torch.nn as nn
import matplotlib.pyplot as plt

from torch.optim import Adam
from torch.utils.data import DataLoader, TensorDataset

# %%
DECK = 4 * (list(range(2, 12)) + [10, 10, 10])

class Value(nn.Module):
    def __init__(self):
        super().__init__()
        self.lin1 = nn.Linear(8, 12)
        self.lin2 = nn.Linear(12, 12)
        self.lin3 = nn.Linear(12, 12)
        self.lin4 = nn.Linear(12, 1)
        

    def forward(self, x):
        x = self.lin1(x)
        x = torch.relu(x)
        x = self.lin2(x)
        x = torch.relu(x)
        x = self.lin3(x)
        x = torch.relu(x)
        return self.lin4(x)
    
class Policy(nn.Module):
    def __init__(self):
        super().__init__()
        self.lin1 = nn.Linear(8, 12)
        self.lin2 = nn.Linear(12, 12)
        self.lin3 = nn.Linear(12, 12)
        self.lin4 = nn.Linear(12, 4) # double, split, stand, hit
        self.softmax = torch.softmax

    def forward(self, x):
        x = self.lin1(x)
        x = torch.relu(x)
        x = self.lin2(x)
        x = torch.relu(x)
        x = self.lin3(x)
        x = torch.relu(x)
        x = self.lin4(x)
        return self.softmax(x, dim = -1)

# %%
def get_bet(count):
    return 10.

def is_soft(c1, c2):
    return c1 == 11 or c2 == 11

def get_score(hand, c, soft):
    """returns the score and its softness given the existing hand and a new card"""
    if c != 11 and not soft:
        return False, hand + c

    if c == 11 and not soft: # if valid with 1 or 11, then is still soft (and add 11). else add 1 only
        if hand + 11 <= 21: # and by extension vaild with hand + 1
            return True, hand + 11

        return False, hand + 1

    if c != 11 and soft: # if total > 21, then subtract 10 and it's no longer soft. else, add the card and it's still soft 
        if hand + c > 21:
            return False, hand + c - 10

        return True, hand + c

    # else c == 11 and it's soft
    # my argument: we add one and it remains soft since by construction, a hand cannot be soft
    # unless it is of total at least 11
    return True, hand + 1

# %%
### TROUBLESHOOTING GET SCORE
#for p in range(2, 21): # isch guet
#    for c in range(2, 12):
#        s, np = get_score(p, c, False)
#        print(p, 'plus', c, 'is', np, s)

#for p in range(11, 21): # i think it's good but i don't want to check rn :)
#    for c in range(2, 12):
#        s, np = get_score(p, c, True)
#        print(p, 'plus', c, 'is', np, s)

# %%
def blackjack(c1, c2):
    return (c1 == 11 and c2 == 10) or (c1 == 10 and c2 == 11)

# %%
def g(A, epsilon):
    return (1 + epsilon) * A * (A >= 0) + (1 - epsilon) * A * (A < 0)

# %%
def do_game(policy, verbose = False):
    """
    does rounds of blackjack until the shoe is sufficiently low (here defined to be 20 cards) 
    """
    shoe = 8 * DECK
    random.shuffle(shoe)

    count = 0.
    winnings = 0.

    S = []
    P = []
    A = []
    R = []

    while len(shoe) > 20:
        if verbose:
            print('\n=== NEW ROUND ===')
            
        bet = get_bet(count)
        s, p, a, reward = round(shoe, policy, bet, verbose)

        S += s
        P += p
        A += a
        R += [reward for _ in s]

        winnings += reward

        #print(len(s), len(p), len(a))

    return S, P, A, R, winnings

def round(shoe, policy, bet, verbose = False):
    """
    one round of blackjack
    """

    # initialize lists of states and actions to be undertaken
    states = []
    probabilities = []
    actions = []

    penalty = -1000.
    bet2 = 0.
    
    # deal player cards
    c1 = shoe.pop(0)
    c2 = shoe.pop(0)

    player = 0.
    dealer = 0.
    
    splittable = c1 == c2

    soft, player = get_score(player, c1, False)
    soft, player = get_score(player, c2, soft)

    # deal dealer cards
    d1 = shoe.pop(0)
    d2 = shoe.pop(0)

    soft_dealer, dealer = get_score(dealer, d1, False)

    # initiallize state vector
    # splittable | doublable | soft | score | doublable2 | soft2 | score2 | dealer upcard
    state = torch.tensor(
        [
            splittable, # can split or not
            True, # can double 
            soft, # soft or not
            player, # player score 
            False, False, 0.,
            dealer
        ])


    # check for blackjacks
    if blackjack(d1, d2) and not blackjack(c1, c2): # dealer, not player
        if verbose:
            print('Dealer blackjack')
            print('Payout:', -1 * bet)
            
        return states, probabilities, actions, -1 * bet

    elif blackjack(d1, d2) and blackjack(c1, c2): # both
        if verbose:
            print('Double blackjack')
            print('Payout:', 0.)
            
        return states, probabilities, actions, 0.

    elif blackjack(c1, c2):
        if verbose:
            print('Blackjack!')
            print('Payout:', 1.5 * bet)
        
        return states, probabilities, actions, 1.5 * bet

    # print what's up
    if verbose:
        print('Player:', 'soft' if soft else '', player, '| Dealer:', d1)


    # player gets to 21 by doing actions
    while state[3] < 21: 

        states.append(state)
        
        # get action - 0 stand, 1 hit, 2 double, 3 split
        probs = policy(state).detach()
        action = torch.distributions.Categorical(probs = probs).sample().item()

        probabilities.append(probs)
        actions.append(action)

        if verbose:
            print('Action:', ['stand', 'hit', 'double', 'split'][action])

        if action == 0:
            break

        if action == 1:
            c = shoe.pop(0)
            state[2], state[3] = get_score(state[3], c, state[2])

            # update so no splits or doubles
            state[0] = False
            state[1] = False

            if verbose:
                print('Player:', 'soft' if state[2] else '', state[3].item())

        if action == 2:
            if not state[1]: # if we doubled when we were not permitted
                if verbose:
                    print('Invalid!')

                return states, probabilities, actions, penalty

            # else it's just the same as above
            c = shoe.pop(0)
            state[2], state[3] = get_score(state[3], c, state[2])

            # update so no splits or doubles
            state[0] = False
            state[1] = False

            # double the bet
            bet *= 2

            if verbose:
                print('Player:', 'soft' if state[2] else '', state[3].item())

            break

        if action == 3:
            if not state[0]:
                if verbose:
                    print('Invalid!')

                return states, probabilities, actions, penalty

            # can no longer split
            state[0] = False

            # redistribute cards
            if state[2] and state[3] == 12: # if double aces
                state[3] = 11.
                state[6] = 11.

                state[2] = True
                state[5] = True

            else: # otherwise it's simplly half the score
                state[3] /= 2
                state[6] = state[3]

                state[2] = False
                state[5] = False

            # add two new cards
            c = shoe.pop(0)
            state[2], state[3] = get_score(state[3], c, state[2])

            c = shoe.pop(0)
            state[5], state[6] = get_score(state[6], c, state[5])

            # update doubleables
            state[1] = True
            state[4] = True

            # instantiate the second bet
            bet2 = 1. * bet

            if verbose:
                print('Player:', 'soft' if state[2] else '', state[3].item(), '| Player 2:', 'soft' if state[5] else '', state[6].item())


    # see if the second hand must be processed
    if state[6] != 0:
        while state[6] < 21:

            states.append(state)
            
            probs = policy(state).detach()
            action = torch.distributions.Categorical(probs = probs).sample().item()

            probabilities.append(probs)
            actions.append(action)
    
            if verbose:
                print('Action 2:', ['stand', 'hit', 'double', 'split'][action])
    
            if action == 0:
                break
    
            if action == 1:
                c = shoe.pop(0)
                state[5], state[6] = get_score(state[6], c, state[5])
    
                # update so no doubles
                state[4] = False
    
                if verbose:
                    print('Player 2:', 'soft' if state[5] else '', state[6].item())
    
            if action == 2:
                if not state[4]: # if we doubled when we were not permitted
                    if verbose:
                        print('Invalid!')
    
                    return states, probabilities, actions, penalty
    
                # else it's just the same as above
                c = shoe.pop(0)
                state[5], state[6] = get_score(state[6], c, state[5])
    
                # update so no doubles
                state[4] = False
                bet2 *= 2
    
                if verbose:
                    print('Player 2:', 'soft' if state[5] else '', state[6].item())
    
                break
    
            if action == 3:
                if verbose:
                    print('Invalid!')
    
                return states, probabilities, actions, penalty


    #states.append(state)


    # we may not have to process the dealer hand
    # (1) hand 1 busts and hand 2 doesn't exist ; (2) both hands exist, and both bust
    if state[3] > 21 and state[6] == 0:
        if verbose:
            print('Bust. Payout:', -1 * bet)

        soft_dealer, dealer = get_score(dealer, d2, soft_dealer)
        return states, probabilities, actions, -1 * bet

    if state[3] > 21 and state[6] > 21:
        if verbose:
            print('Both hands bust. Payout:', -1 * (bet + bet2))

        soft_dealer, dealer = get_score(dealer, d2, soft_dealer)
        return states, probabilities, actions, -1 * (bet + bet2)

    
    # otherwise, we must process the dealer hand
    soft_dealer, dealer = get_score(dealer, d2, soft_dealer)

    while dealer < 17:
        d = shoe.pop(0)
        soft_dealer, dealer = get_score(dealer, d, soft_dealer)

    if verbose:
        print('Dealer:', dealer)

    
    # check for dealer bust
    if dealer > 21:
        if verbose:
            print('Player victory. Payout:', (2 * (state[3].item() <= 21) - 1) * bet + (2 * (state[6].item() <= 21) - 1) * bet2)

        return states, probabilities, actions, ((2 * (state[3].item() <= 21) - 1) * bet) + ((2 * (state[6].item() <= 21) - 1) * bet2)


    # do comparisons
    # only first hand ~OR~ first hand and second hand bust
    if state[3] <= 21 and (state[6] == 0 or state[6] > 21): # then it's win loss or tie (already accountued for bust case)
        if state[3] > dealer:
            if verbose:
                print('Payout:', bet - bet2)

            return states, probabilities, actions, bet - bet2

        elif state[3] == dealer:
            if verbose:
                print('Payout:', 0. - bet2)

            return states, probabilities, actions, 0. - bet2

        else: 
            if verbose:
                print('Payout:', -1 * bet - bet2)

            return states, probabilities, actions, -1 * bet - bet2

    # first hand bust, second hand valid
    if state[3] > 21 and state[6] <= 21:
        if state[6] > dealer:
            if verbose:
                print('Payout:', bet2 - bet)

            return states, probabilities, actions, bet - bet2

        elif state[6] == dealer:
            if verbose:
                print('Payout:', 0. - bet)

            return states, probabilities, actions, 0. - bet

        else: 
            if verbose:
                print('Payout:', -1 * bet2 - bet)

            return states, probabilities, actions, -1 * bet2 - bet

    # both hands valid
    if state[3] == dealer:
        if state[6] == dealer:
            if verbose:
                print('Payout:', 0.)
                
            return states, probabilities, actions, 0.
        # else we won or lost
        if verbose:
            print('Payout:', bet2 * (2 * (state[6] > dealer).item() - 1))

        return states, probabilities, actions, bet2 * (2 * (state[6] > dealer).item() - 1)

    elif state[6] == dealer:
        # then just account for first hand, already accounted for equality case
        if verbose:
            print('Payout:', bet * (2 * (state[3] > dealer) - 1).item())
            
        return states, probabilities, actions, bet * (2 * (state[3] > dealer) - 1).item()

    # else both are not ties and eligible for consideration
    if verbose:
        print('Payout:', bet * (2 * (state[3] > dealer) - 1).item() + (bet2 * (2 * (state[6] > dealer) - 1).item()))
    return states, probabilities, actions, bet * (2 * (state[3] > dealer) - 1).item() + (bet2 * (2 * (state[6] > dealer) - 1)).item()

# %%
policy = Policy()

do_game(policy, verbose = True)
# Out:
# === NEW ROUND ===
# Player: soft 19.0 | Dealer: 10
# Action: hit
# Player:  16.0
# Action: split
# Invalid!
#
# === NEW ROUND ===
# Player:  11.0 | Dealer: 10
# Action: hit
# Player:  13.0
# Action: hit
# Player:  19.0
# Action: stand
# Dealer: 20.0
# Payout: -10.0
#
# === NEW ROUND ===
# Player:  11.0 | Dealer: 4
# Action: hit
# Player:  19.0
# Action: double
# Invalid!
#
# === NEW ROUND ===
# Player:  16.0 | Dealer: 5
# Action: hit
# Player:  20.0
# Action: stand
# Dealer: 22.0
# Player victory. Payout: 10.0
#
# === NEW ROUND ===
# Player:  19.0 | Dealer: 11
# Action: split
# Invalid!
#
# === NEW ROUND ===
# Player:  13.0 | Dealer: 10
# Action: hit
# Player:  17.0
# Action: hit
# Player:  22.0
# Bust. Payout: -10.0
#
# === NEW ROUND ===
# Player:  20.0 | Dealer: 9
# Action: hit
# Player:  27.0
# Bust. Payout: -10.0
#
# === NEW ROUND ===
# Player:  16.0 | Dealer: 10
# Action: hit
# Player:  23.0
# Bust. Payout: -10.0
#
# === NEW ROUND ===
# Player: soft 14.0 | Dealer: 9
# Action: double
# Player: soft 15.0
# Dealer: 19.0
# Payout: -20.0
#
# === NEW ROUND ===
# Player:  7.0 | Dealer: 10
# Action: split
# Invalid!
#
# === NEW ROUND ===
# Player:  12.0 | Dealer: 10
# Action: hit
# Player:  22.0
# Bust. Payout: -10.0
#
# === NEW ROUND ===
# Player: soft 19.0 | Dealer: 6
# Action: hit
# Player:  16.0
# Action: split
# Invalid!
#
# === NEW ROUND ===
# Player:  20.0 | Dealer: 6
# Action: split
# Player:  12.0 | Player 2:  20.0
# Action: hit
# Player:  22.0
# Action 2: hit
# Player 2:  27.0
# Both hands bust. Payout: -20.0
#
# === NEW ROUND ===
# Player:  15.0 | Dealer: 10
# Action: stand
# Dealer: 25.0
# Player victory. Payout: 10.0
#
# === NEW ROUND ===
# Player: soft 16.0 | Dealer: 10
# Action: stand
# Dealer: 18.0
# Payout: -10.0
#
# === NEW ROUND ===
# Player:  19.0 | Dealer: 3
# Action: hit
# Player:  21.0
# Dealer: 18.0
# Payout: 10.0
#
# === NEW ROUND ===
# Player:  19.0 | Dealer: 3
# Action: stand
# Dealer: 18.0
# Payout: 10.0
#
# === NEW ROUND ===
# Player:  12.0 | Dealer: 10
# Action: double
# Player:  22.0
# Bust. Payout: -20.0
#
# === NEW ROUND ===
# Player:  18.0 | Dealer: 2
# Action: hit
# Player:  27.0
# Bust. Payout: -10.0
#
# === NEW ROUND ===
# Player:  20.0 | Dealer: 3
# Action: hit
# Player:  30.0
# Bust. Payout: -10.0
#
# === NEW ROUND ===
# Player:  14.0 | Dealer: 3
# Action: hit
# Player:  21.0
# Dealer: 17.0
# Payout: 10.0
#
# === NEW ROUND ===
# Player:  20.0 | Dealer: 6
# Action: double
# Player:  22.0
# Bust. Payout: -20.0
#
# === NEW ROUND ===
# Blackjack!
# Payout: 15.0
#
# === NEW ROUND ===
# Player:  8.0 | Dealer: 10
# Action: hit
# Player:  18.0
# Action: double
# Invalid!
#
# === NEW ROUND ===
# Player:  20.0 | Dealer: 7
# Action: double
# Player:  29.0
# Bust. Payout: -20.0
#
# === NEW ROUND ===
# Player: soft 13.0 | Dealer: 10
# Action: split
# Invalid!
#
# === NEW ROUND ===
# Player:  19.0 | Dealer: 10
# Action: hit
# Player:  20.0
# Action: double
# Invalid!
#
# === NEW ROUND ===
# Player:  10.0 | Dealer: 4
# Action: hit
# Player:  18.0
# Action: split
# Invalid!
#
# === NEW ROUND ===
# Player:  7.0 | Dealer: 10
# Action: split
# Invalid!
#
# === NEW ROUND ===
# Player: soft 12.0 | Dealer: 2
# Action: hit
# Player: soft 14.0
# Action: stand
# Dealer: 17.0
# Payout: -10.0
#
# === NEW ROUND ===
# Player: soft 15.0 | Dealer: 11
# Action: double
# Player: soft 19.0
# Dealer: 17.0
# Payout: 20.0
#
# === NEW ROUND ===
# Blackjack!
# Payout: 15.0
#
# === NEW ROUND ===
# Dealer blackjack
# Payout: -10.0
#
# === NEW ROUND ===
# Player:  19.0 | Dealer: 10
# Action: hit
# Player:  22.0
# Bust. Payout: -10.0
#
# === NEW ROUND ===
# Player:  19.0 | Dealer: 4
# Action: double
# Player:  22.0
# Bust. Payout: -20.0
#
# === NEW ROUND ===
# Player:  17.0 | Dealer: 4
# Action: hit
# Player:  24.0
# Bust. Payout: -10.0
#
# === NEW ROUND ===
# Player:  13.0 | Dealer: 9
# Action: double
# Player:  16.0
# Dealer: 17.0
# Payout: -20.0
#
# === NEW ROUND ===
# Player:  8.0 | Dealer: 5
# Action: stand
# Dealer: 19.0
# Payout: -10.0
#
# === NEW ROUND ===
# Player:  15.0 | Dealer: 7
# Action: stand
# Dealer: 23.0
# Player victory. Payout: 10.0
#
# === NEW ROUND ===
# Player:  7.0 | Dealer: 2
# Action: stand
# Dealer: 21.0
# Payout: -10.0
#
# === NEW ROUND ===
# Player:  13.0 | Dealer: 5
# Action: split
# Invalid!
#
# === NEW ROUND ===
# Player:  12.0 | Dealer: 2
# Action: hit
# Player:  18.0
# Action: hit
# Player:  28.0
# Bust. Payout: -10.0
#
# === NEW ROUND ===
# Player:  10.0 | Dealer: 10
# Action: hit
# Player:  20.0
# Action: hit
# Player:  30.0
# Bust. Payout: -10.0
#
# === NEW ROUND ===
# Player:  14.0 | Dealer: 2
# Action: hit
# Player:  24.0
# Bust. Payout: -10.0
#
# === NEW ROUND ===
# Player:  19.0 | Dealer: 10
# Action: hit
# Player:  21.0
# Dealer: 20.0
# Payout: 10.0
#
# === NEW ROUND ===
# Player:  12.0 | Dealer: 5
# Action: hit
# Player:  21.0
# Dealer: 23.0
# Player victory. Payout: 10.0
#
# === NEW ROUND ===
# Player:  10.0 | Dealer: 8
# Action: stand
# Dealer: 17.0
# Payout: -10.0
#
# === NEW ROUND ===
# Player:  13.0 | Dealer: 10
# Action: hit
# Player:  16.0
# Action: double
# Invalid!
#
# === NEW ROUND ===
# Player:  13.0 | Dealer: 2
# Action: hit
# Player:  20.0
# Action: split
# Invalid!
#
# === NEW ROUND ===
# Player: soft 14.0 | Dealer: 5
# Action: hit
# Player:  14.0
# Action: hit
# Player:  23.0
# Bust. Payout: -10.0
#
# === NEW ROUND ===
# Player:  18.0 | Dealer: 8
# Action: stand
# Dealer: 19.0
# Payout: -10.0
#
# === NEW ROUND ===
# Player:  18.0 | Dealer: 7
# Action: double
# Player:  28.0
# Bust. Payout: -20.0
#
# === NEW ROUND ===
# Player:  20.0 | Dealer: 2
# Action: hit
# Player:  30.0
# Bust. Payout: -10.0
#
# === NEW ROUND ===
# Player:  20.0 | Dealer: 10
# Action: stand
# Dealer: 18.0
# Payout: 10.0
#
# === NEW ROUND ===
# Player:  14.0 | Dealer: 10
# Action: hit
# Player:  24.0
# Bust. Payout: -10.0
#
# === NEW ROUND ===
# Player: soft 17.0 | Dealer: 10
# Action: hit
# Player: soft 18.0
# Action: double
# Invalid!
#
# === NEW ROUND ===
# Player:  17.0 | Dealer: 10
# Action: hit
# Player:  26.0
# Bust. Payout: -10.0
#
# === NEW ROUND ===
# Player:  18.0 | Dealer: 7
# Action: split
# Invalid!
#
# === NEW ROUND ===
# Player: soft 18.0 | Dealer: 10
# Action: hit
# Player: soft 21.0
# Dealer: 20.0
# Payout: 10.0
#
# === NEW ROUND ===
# Player:  18.0 | Dealer: 10
# Action: hit
# Player:  28.0
# Bust. Payout: -10.0
#
# === NEW ROUND ===
# Player:  12.0 | Dealer: 8
# Action: hit
# Player:  22.0
# Bust. Payout: -10.0
#
# === NEW ROUND ===
# Player: soft 20.0 | Dealer: 9
# Action: stand
# Dealer: 25.0
# Player victory. Payout: 10.0
#
# === NEW ROUND ===
# Player: soft 20.0 | Dealer: 2
# Action: split
# Invalid!
#
# === NEW ROUND ===
# Player:  14.0 | Dealer: 9
# Action: hit
# Player:  18.0
# Action: double
# Invalid!
#
# === NEW ROUND ===
# Player:  17.0 | Dealer: 4
# Action: stand
# Dealer: 17.0
# Payout: 0.0
#
# === NEW ROUND ===
# Player:  15.0 | Dealer: 6
# Action: split
# Invalid!
#
# === NEW ROUND ===
# Player:  16.0 | Dealer: 4
# Action: hit
# Player:  17.0
# Action: stand
# Dealer: 23.0
# Player victory. Payout: 10.0
#
# === NEW ROUND ===
# Player:  12.0 | Dealer: 10
# Action: hit
# Player:  15.0
# Action: split
# Invalid!
#
# === NEW ROUND ===
# Player:  12.0 | Dealer: 11
# Action: hit
# Player:  18.0
# Action: hit
# Player:  26.0
# Bust. Payout: -10.0
#
# === NEW ROUND ===
# Player: soft 16.0 | Dealer: 10
# Action: double
# Player:  14.0
# Dealer: 18.0
# Payout: -20.0
#
# === NEW ROUND ===
# Player:  17.0 | Dealer: 8
# Action: hit
# Player:  27.0
# Bust. Payout: -10.0
#
# === NEW ROUND ===
# Player:  12.0 | Dealer: 10
# Action: stand
# Dealer: 18.0
# Payout: -10.0
#
# === NEW ROUND ===
# Player:  17.0 | Dealer: 8
# Action: split
# Invalid!
#
# === NEW ROUND ===
# Player:  19.0 | Dealer: 2
# Action: split
# Invalid!
#
# === NEW ROUND ===
# Player:  20.0 | Dealer: 10
# Action: hit
# Player:  30.0
# Bust. Payout: -10.0
#
# === NEW ROUND ===
# Player:  15.0 | Dealer: 11
# Action: split
# Invalid!
#
# === NEW ROUND ===
# Player:  13.0 | Dealer: 8
# Action: hit
# Player:  19.0
# Action: split
# Invalid!
#
# === NEW ROUND ===
# Player:  16.0 | Dealer: 5
# Action: split
# Invalid!
#
# === NEW ROUND ===
# Player:  14.0 | Dealer: 10
# Action: split
# Invalid!
# ([tensor([ 0.,  0.,  0., 16.,  0.,  0.,  0., 10.]),
#   tensor([ 0.,  0.,  0., 16.,  0.,  0.,  0., 10.]),
#   tensor([ 0.,  0.,  0., 19.,  0.,  0.,  0., 10.]),
#   tensor([ 0.,  0.,  0., 19.,  0.,  0.,  0., 10.]),
#   tensor([ 0.,  0.,  0., 19.,  0.,  0.,  0., 10.]),
#   tensor([ 0.,  0.,  0., 19.,  0.,  0.,  0.,  4.]),
#   tensor([ 0.,  0.,  0., 19.,  0.,  0.,  0.,  4.]),
#   tensor([ 0.,  0.,  0., 20.,  0.,  0.,  0.,  5.]),
#   tensor([ 0.,  0.,  0., 20.,  0.,  0.,  0.,  5.]),
#   tensor([ 0.,  1.,  0., 19.,  0.,  0.,  0., 11.]),
#   tensor([ 0.,  0.,  0., 22.,  0.,  0.,  0., 10.]),
#   tensor([ 0.,  0.,  0., 22.,  0.,  0.,  0., 10.]),
#   tensor([ 0.,  0.,  0., 27.,  0.,  0.,  0.,  9.]),
#   tensor([ 0.,  0.,  0., 23.,  0.,  0.,  0., 10.]),
#   tensor([ 0.,  0.,  1., 15.,  0.,  0.,  0.,  9.]),
#   tensor([ 0.,  1.,  0.,  7.,  0.,  0.,  0., 10.]),
#   tensor([ 0.,  0.,  0., 22.,  0.,  0.,  0., 10.]),
#   tensor([ 0.,  0.,  0., 16.,  0.,  0.,  0.,  6.]),
#   tensor([ 0.,  0.,  0., 16.,  0.,  0.,  0.,  6.]),
#   tensor([ 0.,  0.,  0., 22.,  0.,  0., 27.,  6.]),
#   tensor([ 0.,  0.,  0., 22.,  0.,  0., 27.,  6.]),
#   tensor([ 0.,  0.,  0., 22.,  0.,  0., 27.,  6.]),
#   tensor([ 0.,  1.,  0., 15.,  0.,  0.,  0., 10.]),
#   tensor([ 0.,  1.,  1., 16.,  0.,  0.,  0., 10.]),
#   tensor([ 0.,  0.,  0., 21.,  0.,  0.,  0.,  3.]),
#   tensor([ 0.,  1.,  0., 19.,  0.,  0.,  0.,  3.]),
#   tensor([ 0.,  0.,  0., 22.,  0.,  0.,  0., 10.]),
#   tensor([ 0.,  0.,  0., 27.,  0.,  0.,  0.,  2.]),
#   tensor([ 0.,  0.,  0., 30.,  0.,  0.,  0.,  3.]),
#   tensor([ 0.,  0.,  0., 21.,  0.,  0.,  0.,  3.]),
#   tensor([ 0.,  0.,  0., 22.,  0.,  0.,  0.,  6.]),
#   tensor([ 0.,  0.,  0., 18.,  0.,  0.,  0., 10.]),
#   tensor([ 0.,  0.,  0., 18.,  0.,  0.,  0., 10.]),
#   tensor([ 0.,  0.,  0., 29.,  0.,  0.,  0.,  7.]),
#   tensor([ 0.,  1.,  1., 13.,  0.,  0.,  0., 10.]),
#   tensor([ 0.,  0.,  0., 20.,  0.,  0.,  0., 10.]),
#   tensor([ 0.,  0.,  0., 20.,  0.,  0.,  0., 10.]),
#   tensor([ 0.,  0.,  0., 18.,  0.,  0.,  0.,  4.]),
#   tensor([ 0.,  0.,  0., 18.,  0.,  0.,  0.,  4.]),
#   tensor([ 0.,  1.,  0.,  7.,  0.,  0.,  0., 10.]),
#   tensor([ 0.,  0.,  1., 14.,  0.,  0.,  0.,  2.]),
#   tensor([ 0.,  0.,  1., 14.,  0.,  0.,  0.,  2.]),
#   tensor([ 0.,  0.,  1., 19.,  0.,  0.,  0., 11.]),
#   tensor([ 0.,  0.,  0., 22.,  0.,  0.,  0., 10.]),
#   tensor([ 0.,  0.,  0., 22.,  0.,  0.,  0.,  4.]),
#   tensor([ 0.,  0.,  0., 24.,  0.,  0.,  0.,  4.]),
#   tensor([ 0.,  0.,  0., 16.,  0.,  0.,  0.,  9.]),
#   tensor([0., 1., 0., 8., 0., 0., 0., 5.]),
#   tensor([ 0.,  1.,  0., 15.,  0.,  0.,  0.,  7.]),
#   tensor([0., 1., 0., 7., 0., 0., 0., 2.]),
#   tensor([ 0.,  1.,  0., 13.,  0.,  0.,  0.,  5.]),
#   tensor([ 0.,  0.,  0., 28.,  0.,  0.,  0.,  2.]),
#   tensor([ 0.,  0.,  0., 28.,  0.,  0.,  0.,  2.]),
#   tensor([ 0.,  0.,  0., 30.,  0.,  0.,  0., 10.]),
#   tensor([ 0.,  0.,  0., 30.,  0.,  0.,  0., 10.]),
#   tensor([ 0.,  0.,  0., 24.,  0.,  0.,  0.,  2.]),
#   tensor([ 0.,  0.,  0., 21.,  0.,  0.,  0., 10.]),
#   tensor([ 0.,  0.,  0., 21.,  0.,  0.,  0.,  5.]),
#   tensor([ 0.,  1.,  0., 10.,  0.,  0.,  0.,  8.]),
#   tensor([ 0.,  0.,  0., 16.,  0.,  0.,  0., 10.]),
#   tensor([ 0.,  0.,  0., 16.,  0.,  0.,  0., 10.]),
#   tensor([ 0.,  0.,  0., 20.,  0.,  0.,  0.,  2.]),
#   tensor([ 0.,  0.,  0., 20.,  0.,  0.,  0.,  2.]),
#   tensor([ 0.,  0.,  0., 23.,  0.,  0.,  0.,  5.]),
#   tensor([ 0.,  0.,  0., 23.,  0.,  0.,  0.,  5.]),
#   tensor([ 0.,  1.,  0., 18.,  0.,  0.,  0.,  8.]),
#   tensor([ 0.,  0.,  0., 28.,  0.,  0.,  0.,  7.]),
#   tensor([ 0.,  0.,  0., 30.,  0.,  0.,  0.,  2.]),
#   tensor([ 1.,  1.,  0., 20.,  0.,  0.,  0., 10.]),
#   tensor([ 0.,  0.,  0., 24.,  0.,  0.,  0., 10.]),
#   tensor([ 0.,  0.,  1., 18.,  0.,  0.,  0., 10.]),
#   tensor([ 0.,  0.,  1., 18.,  0.,  0.,  0., 10.]),
#   tensor([ 0.,  0.,  0., 26.,  0.,  0.,  0., 10.]),
#   tensor([ 0.,  1.,  0., 18.,  0.,  0.,  0.,  7.]),
#   tensor([ 0.,  0.,  1., 21.,  0.,  0.,  0., 10.]),
#   tensor([ 0.,  0.,  0., 28.,  0.,  0.,  0., 10.]),
#   tensor([ 0.,  0.,  0., 22.,  0.,  0.,  0.,  8.]),
#   tensor([ 0.,  1.,  1., 20.,  0.,  0.,  0.,  9.]),
#   tensor([ 0.,  1.,  1., 20.,  0.,  0.,  0.,  2.]),
#   tensor([ 0.,  0.,  0., 18.,  0.,  0.,  0.,  9.]),
#   tensor([ 0.,  0.,  0., 18.,  0.,  0.,  0.,  9.]),
#   tensor([ 0.,  1.,  0., 17.,  0.,  0.,  0.,  4.]),
#   tensor([ 0.,  1.,  0., 15.,  0.,  0.,  0.,  6.]),
#   tensor([ 0.,  0.,  0., 17.,  0.,  0.,  0.,  4.]),
#   tensor([ 0.,  0.,  0., 17.,  0.,  0.,  0.,  4.]),
#   tensor([ 0.,  0.,  0., 15.,  0.,  0.,  0., 10.]),
#   tensor([ 0.,  0.,  0., 15.,  0.,  0.,  0., 10.]),
#   tensor([ 0.,  0.,  0., 26.,  0.,  0.,  0., 11.]),
#   tensor([ 0.,  0.,  0., 26.,  0.,  0.,  0., 11.]),
#   tensor([ 0.,  0.,  0., 14.,  0.,  0.,  0., 10.]),
#   tensor([ 0.,  0.,  0., 27.,  0.,  0.,  0.,  8.]),
#   tensor([ 0.,  1.,  0., 12.,  0.,  0.,  0., 10.]),
#   tensor([ 0.,  1.,  0., 17.,  0.,  0.,  0.,  8.]),
#   tensor([ 0.,  1.,  0., 19.,  0.,  0.,  0.,  2.]),
#   tensor([ 0.,  0.,  0., 30.,  0.,  0.,  0., 10.]),
#   tensor([ 0.,  1.,  0., 15.,  0.,  0.,  0., 11.]),
#   tensor([ 0.,  0.,  0., 19.,  0.,  0.,  0.,  8.]),
#   tensor([ 0.,  0.,  0., 19.,  0.,  0.,  0.,  8.]),
#   tensor([ 0.,  1.,  0., 16.,  0.,  0.,  0.,  5.]),
#   tensor([ 0.,  1.,  0., 14.,  0.,  0.,  0., 10.])],
#  [tensor([0.2181, 0.4002, 0.1286, 0.2530]),
#   tensor([0.1989, 0.4288, 0.1311, 0.2412]),
#   tensor([0.1988, 0.4063, 0.1478, 0.2471]),
#   tensor([0.1997, 0.4152, 0.1402, 0.2449]),
#   tensor([0.1983, 0.4311, 0.1268, 0.2438]),
#   tensor([0.2283, 0.3300, 0.1672, 0.2746]),
#   tensor([0.2330, 0.3298, 0.1522, 0.2850]),
#   tensor([0.2316, 0.3427, 0.1517, 0.2740]),
#   tensor([0.2295, 0.3434, 0.1461, 0.2809]),
#   tensor([0.1957, 0.4526, 0.1205, 0.2312]),
#   tensor([0.1985, 0.4180, 0.1408, 0.2427]),
#   tensor([0.1966, 0.4317, 0.1301, 0.2416]),
#   tensor([0.2036, 0.4202, 0.1291, 0.2471]),
#   tensor([0.1979, 0.4341, 0.1310, 0.2370]),
#   tensor([0.2155, 0.3875, 0.1425, 0.2545]),
#   tensor([0.2010, 0.3824, 0.1637, 0.2530]),
#   tensor([0.1986, 0.4121, 0.1443, 0.2449]),
#   tensor([0.2423, 0.3335, 0.1435, 0.2807]),
#   tensor([0.2182, 0.3611, 0.1504, 0.2702]),
#   tensor([0.2228, 0.3669, 0.1412, 0.2691]),
#   tensor([0.2533, 0.3973, 0.1063, 0.2431]),
#   tensor([0.2741, 0.4264, 0.0854, 0.2141]),
#   tensor([0.1980, 0.4297, 0.1341, 0.2382]),
#   tensor([0.2122, 0.4043, 0.1343, 0.2492]),
#   tensor([0.2476, 0.3151, 0.1503, 0.2869]),
#   tensor([0.2476, 0.3151, 0.1503, 0.2869]),
#   tensor([0.1986, 0.4121, 0.1443, 0.2449]),
#   tensor([0.2511, 0.3023, 0.1562, 0.2905]),
#   tensor([0.2403, 0.3263, 0.1501, 0.2833]),
#   tensor([0.2385, 0.3133, 0.1650, 0.2832]),
#   tensor([0.2228, 0.3669, 0.1412, 0.2691]),
#   tensor([0.2005, 0.3883, 0.1595, 0.2517]),
#   tensor([0.1966, 0.4322, 0.1286, 0.2426]),
#   tensor([0.2172, 0.3828, 0.1373, 0.2628]),
#   tensor([0.2076, 0.3990, 0.1439, 0.2495]),
#   tensor([0.2036, 0.4323, 0.1245, 0.2396]),
#   tensor([0.2000, 0.4299, 0.1251, 0.2450]),
#   tensor([0.2256, 0.3310, 0.1696, 0.2737]),
#   tensor([0.2314, 0.3288, 0.1551, 0.2846]),
#   tensor([0.2010, 0.3824, 0.1637, 0.2530]),
#   tensor([0.2397, 0.2926, 0.1799, 0.2879]),
#   tensor([0.2437, 0.2875, 0.1746, 0.2942]),
#   tensor([0.2018, 0.4199, 0.1355, 0.2429]),
#   tensor([0.2036, 0.4323, 0.1245, 0.2396]),
#   tensor([0.2423, 0.3279, 0.1474, 0.2825]),
#   tensor([0.2387, 0.3272, 0.1531, 0.2810]),
#   tensor([0.2040, 0.4086, 0.1426, 0.2449]),
#   tensor([0.2252, 0.3406, 0.1678, 0.2664]),
#   tensor([0.2178, 0.3790, 0.1450, 0.2582]),
#   tensor([0.2298, 0.3003, 0.1863, 0.2837]),
#   tensor([0.2263, 0.3454, 0.1582, 0.2702]),
#   tensor([0.2400, 0.3000, 0.1741, 0.2858]),
#   tensor([0.2413, 0.3054, 0.1611, 0.2923]),
#   tensor([0.1993, 0.4003, 0.1515, 0.2489]),
#   tensor([0.2000, 0.4299, 0.1251, 0.2450]),
#   tensor([0.2435, 0.3008, 0.1685, 0.2872]),
#   tensor([0.2036, 0.4323, 0.1245, 0.2396]),
#   tensor([0.2244, 0.3463, 0.1604, 0.2689]),
#   tensor([0.2096, 0.3820, 0.1549, 0.2535]),
#   tensor([0.1985, 0.4180, 0.1408, 0.2427]),
#   tensor([0.1989, 0.4288, 0.1311, 0.2412]),
#   tensor([0.2416, 0.3004, 0.1717, 0.2863]),
#   tensor([0.2446, 0.3076, 0.1548, 0.2930]),
#   tensor([0.2390, 0.3191, 0.1600, 0.2818]),
#   tensor([0.2205, 0.3455, 0.1592, 0.2748]),
#   tensor([0.2168, 0.3941, 0.1347, 0.2543]),
#   tensor([0.2232, 0.3759, 0.1388, 0.2620]),
#   tensor([0.2466, 0.3150, 0.1517, 0.2867]),
#   tensor([0.1963, 0.4399, 0.1250, 0.2388]),
#   tensor([0.1983, 0.4239, 0.1374, 0.2404]),
#   tensor([0.2143, 0.4028, 0.1324, 0.2505]),
#   tensor([0.2097, 0.4021, 0.1327, 0.2555]),
#   tensor([0.1995, 0.4353, 0.1282, 0.2369]),
#   tensor([0.2232, 0.3759, 0.1388, 0.2620]),
#   tensor([0.2164, 0.4014, 0.1305, 0.2518]),
#   tensor([0.2016, 0.4338, 0.1264, 0.2382]),
#   tensor([0.2097, 0.3923, 0.1479, 0.2502]),
#   tensor([0.2262, 0.3812, 0.1305, 0.2621]),
#   tensor([0.2610, 0.2944, 0.1500, 0.2946]),
#   tensor([0.2039, 0.4131, 0.1393, 0.2437]),
#   tensor([0.2037, 0.4127, 0.1330, 0.2507]),
#   tensor([0.2387, 0.3272, 0.1531, 0.2810]),
#   tensor([0.2240, 0.3611, 0.1494, 0.2656]),
#   tensor([0.2369, 0.3268, 0.1561, 0.2802]),
#   tensor([0.2301, 0.3281, 0.1573, 0.2845]),
#   tensor([0.1986, 0.4121, 0.1443, 0.2449]),
#   tensor([0.1995, 0.4253, 0.1336, 0.2417]),
#   tensor([0.1933, 0.4216, 0.1426, 0.2426]),
#   tensor([0.1920, 0.4496, 0.1238, 0.2347]),
#   tensor([0.2122, 0.4043, 0.1343, 0.2492]),
#   tensor([0.2149, 0.3954, 0.1367, 0.2531]),
#   tensor([0.1986, 0.4121, 0.1443, 0.2449]),
#   tensor([0.2149, 0.3954, 0.1367, 0.2531]),
#   tensor([0.2530, 0.3026, 0.1532, 0.2912]),
#   tensor([0.1963, 0.4399, 0.1250, 0.2388]),
#   tensor([0.1926, 0.4393, 0.1324, 0.2358]),
#   tensor([0.2097, 0.3962, 0.1446, 0.2495]),
#   tensor([0.2115, 0.3937, 0.1356, 0.2593]),
#   tensor([0.2316, 0.3427, 0.1517, 0.2740]),
#   tensor([0.1983, 0.4239, 0.1374, 0.2404])],
#  [1,
#   3,
#   1,
#   1,
#   0,
#   1,
#   2,
#   1,
#   0,
#   3,
#   1,
#   1,
#   1,
#   1,
#   2,
#   3,
#   1,
#   1,
#   3,
#   3,
#   1,
#   1,
#   0,
#   0,
#   1,
#   0,
#   2,
#   1,
#   1,
#   1,
#   2,
#   1,
#   2,
#   2,
#   3,
#   1,
#   2,
#   1,
#   3,
#   3,
#   1,
#   0,
#   2,
#   1,
#   2,
#   1,
#   2,
#   0,
#   0,
#   0,
#   3,
#   1,
#   1,
#   1,
#   1,
#   1,
#   1,
#   1,
#   0,
#   1,
#   2,
#   1,
#   3,
#   1,
#   1,
#   0,
#   2,
#   1,
#   0,
#   1,
#   1,
#   2,
#   1,
#   3,
#   1,
#   1,
#   1,
#   0,
#   3,
#   1,
#   2,
#   0,
#   3,
#   1,
#   0,
#   1,
#   3,
#   1,
#   1,
#   2,
#   1,
#   0,
#   3,
#   3,
#   1,
#   3,
#   1,
#   3,
#   3,
#   3],
#  [-1000.0,
#   -1000.0,
#   -10.0,
#   -10.0,
#   -10.0,
#   -1000.0,
#   -1000.0,
#   10.0,
#   10.0,
#   -1000.0,
#   -10.0,
#   -10.0,
#   -10.0,
#   -10.0,
#   -20.0,
#   -1000.0,
#   -10.0,
#   -1000.0,
#   -1000.0,
#   -20.0,
#   -20.0,
#   -20.0,
#   10.0,
#   -10.0,
#   10.0,
#   10.0,
#   -20.0,
#   -10.0,
#   -10.0,
#   10.0,
#   -20.0,
#   -1000.0,
#   -1000.0,
#   -20.0,
#   -1000.0,
#   -1000.0,
#   -1000.0,
#   -1000.0,
#   -1000.0,
#   -1000.0,
#   -10.0,
#   -10.0,
#   20.0,
#   -10.0,
#   -20.0,
#   -10.0,
#   -20.0,
#   -10.0,
#   10.0,
#   -10.0,
#   -1000.0,
#   -10.0,
#   -10.0,
#   -10.0,
#   -10.0,
#   -10.0,
#   10.0,
#   10.0,
#   -10.0,
#   -1000.0,
#   -1000.0,
#   -1000.0,
#   -1000.0,
#   -10.0,
#   -10.0,
#   -10.0,
#   -20.0,
#   -10.0,
#   10.0,
#   -10.0,
#   -1000.0,
#   -1000.0,
#   -10.0,
#   -1000.0,
#   10.0,
#   -10.0,
#   -10.0,
#   10.0,
#   -1000.0,
#   -1000.0,
#   -1000.0,
#   0.0,
#   -1000.0,
#   10.0,
#   10.0,
#   -1000.0,
#   -1000.0,
#   -10.0,
#   -10.0,
#   -20.0,
#   -10.0,
#   -10.0,
#   -1000.0,
#   -1000.0,
#   -10.0,
#   -1000.0,
#   -1000.0,
#   -1000.0,
#   -1000.0,
#   -1000.0],
#  -25300.0)

# %%
def train(policy, value, games = 10, epochs = 10):

    optimizer_value = Adam(value.parameters(), lr = 1e-3)
    optimizer_policy = Adam(policy.parameters(), lr = 1e-3)

    batch_size = 20
    W = []

    for epoch in range(epochs):

        S = []
        P = []
        A = []
        R = []

        winnings = 0.

        # generate games
        for _ in range(games):

            s, p, a, r, w = do_game(policy, verbose = False)

            S += s
            P += p
            A += a
            R += r
            
            winnings += w

        # tensorize things for easy computation + advantage estimation        
        S = torch.stack(S)
        P = torch.stack(P)
        Ai = torch.tensor(A)
        A = Ai.reshape(-1, 1)
        R = torch.tensor(R).reshape(-1, 1)

        V = R - value(S).detach()

        dataset = DataLoader(TensorDataset(S, P, Ai, A, R, V), batch_size = batch_size)
        
        # policy training loop        
        for _ in range(500):
            loss = 0.

            for s, p, ai, a, r, v in dataset:
                N = s.shape[0]

                optimizer_policy.zero_grad()
                probs = policy(s)
                
                first_argument = v * probs[torch.arange(N), ai].reshape(-1, 1) / p
                second_argument = g(v, 1e-2)
                
                li = -1 * torch.sum(torch.min(first_argument, second_argument)) # multiply by negative 1 so it goes up
                
                li.backward()
                optimizer_policy.step()

                loss += li.detach()

            #print(loss)


        # value training loop
        for _ in range(500):
            loss = 0.

            for s, p, ai, a, r, v in dataset:
                optimizer_value.zero_grad()
                
                val = value(s)
                li = torch.mean((val - r)**2)
                
                li.backward()
                optimizer_value.step()

                loss += li.detach()

            #print(loss)


        # print the important things
        print('=== Epoch', epoch, '| Winnings:', winnings, '===')
        W.append(winnings)

    return W

# %%
value = Value()
policy = Policy()

train(policy, value)
# Out:
# tensor(1317137.5000)
# tensor(1164149.5000)
# tensor(1156219.5000)
# tensor(1155837.6250)
# tensor(1155516.2500)
# tensor(1155321.7500)
# tensor(1155119.8750)
# tensor(1154902.3750)
# tensor(1154787.1250)
# tensor(1154523.6250)
# tensor(1154290.6250)
# tensor(1154147.)
# tensor(1153956.1250)
# tensor(1153810.5000)
# tensor(1153686.3750)
# tensor(1153525.5000)
# tensor(1153165.6250)
# tensor(1153217.5000)
# tensor(1152963.6250)
# tensor(1152608.2500)
# tensor(1152514.3750)
# tensor(1152061.5000)
# tensor(1151855.8750)
# tensor(1151672.1250)
# tensor(1151383.2500)
# tensor(1151207.8750)
# tensor(1151142.)
# tensor(1150934.3750)
# tensor(1150701.)
# tensor(1150353.8750)
# tensor(1149993.)
# tensor(1149809.3750)
# tensor(1149268.2500)
# tensor(1149345.2500)
# tensor(1149112.1250)
# tensor(1148898.3750)
# tensor(1148967.5000)
# tensor(1148837.8750)
# tensor(1148595.)
# tensor(1148775.6250)
# tensor(1148568.6250)
# tensor(1148206.5000)
# tensor(1148317.1250)
# tensor(1148316.7500)
# tensor(1147661.3750)
# tensor(1147484.1250)
# tensor(1147663.2500)
# tensor(1147668.8750)
# tensor(1147231.6250)
# tensor(1147044.7500)
# tensor(1146835.3750)
# tensor(1146832.1250)
# tensor(1146588.5000)
# tensor(1147068.)
# tensor(1146915.8750)
# tensor(1146877.8750)
# tensor(1146481.)
# tensor(1146119.8750)
# tensor(1145854.7500)
# tensor(1145696.2500)
# tensor(1145661.2500)
# tensor(1145363.3750)
# tensor(1145551.3750)
# tensor(1145215.2500)
# tensor(1145430.6250)
# tensor(1145190.5000)
# tensor(1145047.7500)
# tensor(1144980.1250)
# tensor(1145052.3750)
# tensor(1145155.7500)
# tensor(1146303.)
# tensor(1146110.)
# tensor(1145047.2500)
# tensor(1144997.1250)
# tensor(1144905.5000)
# tensor(1144897.2500)
# tensor(1144835.5000)
# tensor(1144579.5000)
# tensor(1144818.1250)
# tensor(1144535.3750)
# tensor(1144974.7500)
# tensor(1144836.5000)
# tensor(1144655.1250)
# tensor(1144693.2500)
# tensor(1144786.5000)
# tensor(1144828.5000)
# tensor(1144691.3750)
# tensor(1144614.3750)
# tensor(1144711.8750)
# tensor(1144688.8750)
# tensor(1144630.1250)
# tensor(1145813.6250)
# tensor(1145315.8750)
# tensor(1144726.5000)
# tensor(1144942.2500)
# tensor(1144821.8750)
# tensor(1144591.8750)
# tensor(1144493.7500)
# tensor(1144850.5000)
# tensor(1144598.7500)
# tensor(1144805.5000)
# tensor(1144687.)
# tensor(1144621.5000)
# tensor(1144828.6250)
# tensor(1144656.6250)
# tensor(1144663.8750)
# tensor(1144504.3750)
# tensor(1144638.1250)
# tensor(1144856.2500)
# tensor(1144436.2500)
# tensor(1144484.8750)
# tensor(1144718.6250)
# tensor(1144717.)
# tensor(1144503.2500)
# tensor(1144639.6250)
# tensor(1144635.8750)
# tensor(1144488.8750)
# tensor(1144526.1250)
# tensor(1144545.6250)
# tensor(1144488.5000)
# tensor(1144565.)
# tensor(1144509.7500)
# tensor(1144613.3750)
# tensor(1144499.3750)
# tensor(1144648.)
# tensor(1144540.6250)
# tensor(1144556.8750)
# tensor(1144428.1250)
# tensor(1144673.3750)
# tensor(1144435.5000)
# tensor(1146251.2500)
# tensor(1145656.3750)
# tensor(1144677.8750)
# tensor(1144581.6250)
# tensor(1144564.6250)
# tensor(1144537.7500)
# tensor(1144574.6250)
# tensor(1144505.6250)
# tensor(1144757.7500)
# tensor(1144426.5000)
# tensor(1144495.6250)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[115], line 4
#       1 value = Value()
#       2 policy = Policy()
# ----> 4 train(policy, value)
#
# Cell In[114], line 57, in train(policy, value, games, epochs)
#      54     li = -1 * torch.sum(torch.min(first_argument, second_argument)) # multiply by negative 1 so it goes up
#      56     li.backward()
# ---> 57     optimizer_policy.step()
#      59     loss += li.detach()
#      61 print(loss)
#
# File /opt/anaconda3/envs/sml/lib/python3.8/site-packages/torch/optim/optimizer.py:373, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     371 self = cast(Optimizer, self)
#     372 profile_name = f"Optimizer.step#{self.__class__.__name__}.step"
# --> 373 with torch.autograd.profiler.record_function(profile_name):
#     374     # call optimizer step pre hooks
#     375     for pre_hook in chain(_global_optimizer_pre_hooks.values(), self._optimizer_step_pre_hooks.values()):
#     376         result = pre_hook(self, args, kwargs)
#
# File /opt/anaconda3/envs/sml/lib/python3.8/site-packages/torch/autograd/profiler.py:594, in record_function.__init__(self, name, args)
#     593 def __init__(self, name: str, args: Optional[str] = None):
# --> 594     self.name: str = name
#     595     self.args: Optional[str] = args
#     596     # Whether or not we should run record function's end callbacks when exiting.
#
# KeyboardInterrupt:
